# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
# !pip install -q vllm gradio
# !curl -sL https://raw.githubusercontent.com/abuahmad369/llm-budget-forcing/main/app/live_demo.py -o live_demo.py
print("ready")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.9/312.9 MB 5.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 91.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.7/211.7 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 94.1 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.9/184.9 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 96.9 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 77.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 MB 44.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.4/358.4 kB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 MB 35.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.8/755.8 kB 40.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.6/526.6 MB 3.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 3.3 MB/s eta 0:00:000:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 98.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 21.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 85.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.2/366.2 MB 5.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 MB 7.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 91.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 MB 21.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 11.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.0/206.0 MB 8.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 31.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 MB 3.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 3.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 5.3 MB/s eta 0:00:000:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 7.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 55.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 MB 30.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 MB 6.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 MB 12.4 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.7/767.7 kB 46.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 55.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 57.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 64.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.2/793.2 kB 46.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 80.2 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 85.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.7/125.7 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 89.0 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 82.3 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.4/323.4 kB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 90.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 84.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.0/516.0 kB 36.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 MB 38.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 461.2/461.2 kB 31.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.8/149.8 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.2/119.2 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 91.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 23.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.1/808.1 kB 49.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 5.7 MB/s eta 0:00:000:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.4/95.4 kB 108.8 kB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 111.7 kB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 100.3 kB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 32.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 73.6 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 MB 20.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.3/29.3 MB 58.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 88.2 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 MB 41.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.2/201.2 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.8/897.8 kB 50.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 94.7 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.1/78.1 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 92.1 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 MB 44.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 93.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.4/157.4 kB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.3/69.3 MB 25.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.8/927.8 kB 50.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.29.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# grpcio-tools 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.6 which is incompatible.
# ydata-profiling 4.18.4 requires numba<0.63,>=0.60, but you have numba 0.65.0 which is incompatible.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# pylibcudf-cu12 26.2.1 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# numba-cuda 0.22.2 requires cuda-core<1.0.0,>=0.3.2, but you have cuda-core 1.0.1 which is incompatible.
# libcuml-cu12 26.2.0 requires cuda-toolkit[cublas,cufft,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.3.0 which is incompatible.
# rmm-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# cuml-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# cuml-cu12 26.2.0 requires cuda-toolkit[cublas,cufft,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.3.0 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.0 which is incompatible.
# pylibraft-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# cuvs-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.6 which is incompatible.
# cudf-cu12 26.2.1 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# cudf-cu12 26.2.1 requires cuda-toolkit[nvcc,nvrtc]==12.*, but you have cuda-toolkit 13.0.3.0 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.0 which is incompatible.
# libcuvs-cu12 26.2.0 requires cuda-toolkit[cublas,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.3.0 which is incompatible.
# libraft-cu12 26.2.0 requires cuda-toolkit[cublas,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.3.0 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.6 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.44.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.44.0 which is incompatible.
# google-adk 1.29.0 requires starlette<1.0.0,>=0.49.1, but you have starlette 1.6.0 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.44.0 which is incompatible.
# ready

# %%
import sys, importlib
sys.argv = ["live_demo.py", "--backend", "vllm", "--share"]
import live_demo
importlib.reload(live_demo)
live_demo.main()
# Out:
# GPU        : Tesla T4
# VRAM       : 15.64 GB total, 15.53 GB free
# Compute cap: 7.5  (Turing: no bf16)
# vLLM       : available
# float16    : fits, about 257109 tokens of KV cache left
# context window: 18432 tokens (override with --max-len)
# loading model, this takes a few minutes ...
# vLLM gpu_memory_utilization: 0.90 (15.53 GB free of 15.64 GB)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.64k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json: reconstructing file:   0%|          |  0.00B / 11.4MB
# tokenizer.json: downloading bytes:           |  0.00B
# added_tokens.json:   0%|          | 0.00/648 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# INFO 08-24 04:21:16 [api_utils.py:273] non-default args: {'trust_remote_code': True, 'dtype': 'float16', 'max_model_len': 18432, 'gpu_memory_utilization': 0.9, 'disable_log_stats': True, 'model': 'WeiboAI/VibeThinker-3B'}
# INFO 08-24 04:21:32 [model.py:645] Resolved architecture: Qwen2ForCausalLM
# WARNING 08-24 04:21:32 [model.py:2217] Casting torch.bfloat16 to torch.float16.
# INFO 08-24 04:21:32 [model.py:1883] Using max model len 18432
# INFO 08-24 04:21:33 [scheduler.py:242] Chunked prefill is enabled with max_num_batched_tokens=8192.
# INFO 08-24 04:21:33 [kernel.py:306] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native'])
# generation_config.json:   0%|          | 0.00/118 [00:00<?, ?B/s]
# WARNING 08-24 04:21:37 [system_utils.py:157] We must use the `spawn` multiprocessing start method. Overriding VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/usage/troubleshooting.html#python-multiprocessing for more information. Reasons: CUDA is initialized
# (EngineCore pid=272) INFO 08-24 04:21:51 [core.py:121] Initializing a V1 LLM engine (v0.27.1) with config: model='WeiboAI/VibeThinker-3B', speculative_config=None, tokenizer='WeiboAI/VibeThinker-3B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.float16, max_seq_len=18432, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, decode_context_parallel_size=1, dcp_comm_backend=ag_rs, disable_custom_all_reduce=False, quantization=None, quantization_config=None, enforce_eager=False, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False, jit_monitor_mode='warn', jit_monitor_verbose=False), seed=0, served_model_name=WeiboAI/VibeThinker-3B, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'ir_enable_torch_wrap': True, 'splitting_ops': ['vllm::unified_attention_with_output', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::qwen_gdn_attention_core', 'vllm::gdn_attention_core_xpu', 'vllm::olmo_hybrid_gdn_full_forward', 'vllm::sparse_attn_indexer', 'vllm::rocm_aiter_sparse_attn_indexer', 'vllm::deepseek_v4_attention', 'vllm::hpc_rope_norm_forward', 'vllm::unified_kv_cache_update', 'vllm::unified_mla_kv_cache_update'], 'compile_mm_encoder': False, 'cudagraph_mm_encoder': False, 'encoder_cudagraph_token_budgets': [], 'encoder_cudagraph_max_vision_items_per_batch': 0, 'encoder_cudagraph_max_frames_per_batch': None, 'compile_sizes': [], 'compile_ranges_endpoints': [8192], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.FULL_AND_PIECEWISE: (2, 1)>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False, 'enable_qk_norm_rope_fusion': False, 'fuse_rope_kvcache_cat_mla': False, 'fuse_act_padding': False, 'fuse_qk_norm_rope_kvcache': False}, 'max_cudagraph_capture_size': 512, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': False, 'static_all_moe_layers': []}, kernel_config=KernelConfig(ir_op_priority=IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native']), enable_flashinfer_autotune=True, enable_cutedsl_warmup=True, enable_jit_warmup=True, enable_bf16x3_router_gemm=False, moe_backend='auto', linear_backend='auto')
# (EngineCore pid=272) INFO 08-24 04:21:51 [parallel_state.py:1640] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.19.2.2:43559 backend=nccl
# (EngineCore pid=272) INFO 08-24 04:21:51 [parallel_state.py:1977] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (EngineCore pid=272) INFO 08-24 04:21:51 [gpu_worker.py:385] Using V2 Model Runner
# [W824 04:21:51.401449078 socket.cpp:207] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# (EngineCore pid=272) INFO 08-24 04:21:53 [model_runner.py:308] Loading model from scratch...
# (EngineCore pid=272) ERROR 08-24 04:21:53 [fa_utils.py:273] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# (EngineCore pid=272) INFO 08-24 04:21:55 [cuda.py:482] Using TRITON_ATTN attention backend out of potential backends: ['TRITON_ATTN', 'FLEX_ATTENTION'].
# (EngineCore pid=272) INFO 08-24 04:22:30 [weight_utils.py:530] Time spent downloading weights for WeiboAI/VibeThinker-3B: 33.922109 seconds
# (EngineCore pid=272) INFO 08-24 04:22:30 [weight_utils.py:867] Filesystem type for checkpoints: OVERLAY. Checkpoint size: 5.75 GiB. Available RAM: 9.61 GiB.
# (EngineCore pid=272) INFO 08-24 04:22:30 [weight_utils.py:890] Auto-prefetch is disabled because the filesystem (OVERLAY) is not a recognized network FS (NFS/Lustre). If you want to force prefetching, start vLLM with --safetensors-load-strategy=prefetch.
# (EngineCore pid=272) Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  50% Completed | 1/2 [00:04<00:04,  4.31s/it]
# Loading safetensors checkpoint shards: 100% Completed | 2/2 [00:05<00:00,  2.53s/it]
# Loading safetensors checkpoint shards: 100% Completed | 2/2 [00:05<00:00,  2.80s/it]
# (EngineCore pid=272)
# (EngineCore pid=272) INFO 08-24 04:22:36 [default_loader.py:430] Loading weights took 5.63 seconds
# (EngineCore pid=272) INFO 08-24 04:22:37 [model_runner.py:329] Model loading took 5.81 GiB and 44.424129 seconds
# (EngineCore pid=272) WARNING 08-24 04:22:37 [topk_topp_sampler.py:69] FlashInfer top-p/top-k sampling unavailable: unsupported compute capability 7.5; falling back. Set VLLM_USE_FLASHINFER_SAMPLER=0 to silence.
# (EngineCore pid=272) INFO 08-24 04:22:47 [backends.py:1094] Using cache directory: /root/.cache/vllm/torch_compile_cache/888457b26c/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore pid=272) INFO 08-24 04:22:47 [backends.py:1155] Dynamo bytecode transform time: 8.19 s
# (EngineCore pid=272) [rank0]:W0824 04:22:53.737000 272 torch/_inductor/utils.py:1953] Not enough SMs to use max_autotune_gemm mode
# (EngineCore pid=272) INFO 08-24 04:22:56 [backends.py:393] Compiling a graph for compile range (1, 8192) takes 8.55 s
# (EngineCore pid=272) INFO 08-24 04:23:01 [backends.py:920] collected artifacts: 37 entries, 3 artifacts, 4645134 bytes total
# (EngineCore pid=272) INFO 08-24 04:23:01 [decorators.py:708] saved AOT compiled function to /root/.cache/vllm/torch_compile_cache/torch_aot_compile/ed394213579dc2c97caec1ef46997ee9a701fa4cbc43dee12444d63d8e68593a/rank_0_0/model
# (EngineCore pid=272) INFO 08-24 04:23:01 [monitor.py:53] torch.compile took 21.89 s in total
# (EngineCore pid=272) INFO 08-24 04:23:01 [monitor.py:81] Initial profiling/warmup run took 0.11 s
# (EngineCore pid=272) INFO 08-24 04:23:04 [gpu_worker.py:563] Available KV cache memory: 5.8 GiB
# (EngineCore pid=272) INFO 08-24 04:23:04 [kv_cache_utils.py:2235] GPU KV cache size: 168,832 tokens
# (EngineCore pid=272) INFO 08-24 04:23:04 [kv_cache_utils.py:2236] Maximum concurrency for 18,432 tokens per request: 9.16x
# Capturing CUDA graphs (PIECEWISE): 100%|██████████| 51/51 [00:10<00:00,  4.73it/s]
# Capturing CUDA graphs (FULL): 100%|██████████| 35/35 [00:02<00:00, 11.74it/s]
# (EngineCore pid=272) INFO 08-24 04:23:19 [model_runner.py:791] Graph capturing finished in 14 secs, took 0.54 GiB
# (EngineCore pid=272) INFO 08-24 04:23:19 [gpu_worker.py:789] Free memory on device (14.36/14.56 GiB) on startup. Desired GPU memory utilization is (0.9, 13.11 GiB). Actual usage is 6.71 GiB for consumed memory (weights + non-torch), 0.6 GiB for peak activation, and 0.54 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=5487836365` (5.11 GiB) to fit into requested memory, or `--kv-cache-memory=6834515968` (6.37 GiB) to fully utilize gpu memory. Current kv cache memory in use is 5.8 GiB.
# (EngineCore pid=272) INFO 08-24 04:23:33 [jit_monitor.py:79] Kernel JIT monitor activated; monitored JIT compilations during inference will use mode=warn.
# (EngineCore pid=272) INFO 08-24 04:23:33 [core.py:348] init engine (profile, create kv cache, warmup model) took 56.57 s (compilation: 21.89 s)
# (EngineCore pid=272) INFO 08-24 04:23:35 [kernel.py:306] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native'])
# INFO 08-24 04:23:37 [hf.py:540] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# loading AIME 2025 ...
# ready: 30 problems, backend vLLM / float16
# /kaggle/working/live_demo.py:563: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme. Please pass these parameters to launch() instead.
#   with gr.Blocks(title="Budget forcing, live",
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://1634a5b44177cd62b3.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://1634a5b44177cd62b3.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/2 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# (EngineCore pid=272) WARNING 08-24 04:24:16 [jit_monitor.py:135] Triton kernel JIT compilation during inference: kernel_unified_attention. This causes a latency spike; consider extending warmup to cover this shape/config.
# Processed prompts: 100%|██████████| 2/2 [01:05<00:00, 32.68s/it, est. speed input: 1.68 toks/s, output: 59.53 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  6.11it/s, est. speed input: 13118.09 toks/s, output: 24.71 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:48<00:00, 24.32s/it, est. speed input: 2.26 toks/s, output: 63.16 toks/s]
# Rendering prompts:   0%|          | 0/2 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:00<00:00,  7.89it/s, est. speed input: 12758.80 toks/s, output: 39.58 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:31<00:00, 15.69s/it, est. speed input: 3.00 toks/s, output: 65.29 toks/s]
# Rendering prompts:   0%|          | 0/2 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:00<00:00,  9.92it/s, est. speed input: 10883.47 toks/s, output: 39.88 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [01:05<00:00, 32.98s/it, est. speed input: 1.43 toks/s, output: 62.11 toks/s]
# Rendering prompts:   0%|          | 0/2 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:00<00:00,  8.41it/s, est. speed input: 17858.21 toks/s, output: 33.76 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [01:03<00:00, 31.99s/it, est. speed input: 1.47 toks/s, output: 55.43 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [01:28<00:00, 44.13s/it, est. speed input: 1.07 toks/s, output: 51.41 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [01:16<00:00, 38.33s/it, est. speed input: 1.23 toks/s, output: 58.82 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [02:25<00:00, 72.75s/it, est. speed input: 2.42 toks/s, output: 56.30 toks/s]
# Rendering prompts:   0%|          | 0/2 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:00<00:00,  5.01it/s, est. speed input: 21536.32 toks/s, output: 30.10 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [01:33<00:00, 46.88s/it, est. speed input: 2.79 toks/s, output: 58.22 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:48<00:00, 24.14s/it, est. speed input: 2.28 toks/s, output: 63.63 toks/s]
# Rendering prompts:   0%|          | 0/2 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:00<00:00,  9.04it/s, est. speed input: 14621.14 toks/s, output: 36.28 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [02:20<00:00, 70.43s/it, est. speed input: 1.05 toks/s, output: 54.92 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [02:05<00:00, 62.68s/it, est. speed input: 3.88 toks/s, output: 57.18 toks/s]
# Rendering prompts:   0%|          | 0/2 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:00<00:00,  6.69it/s, est. speed input: 25831.77 toks/s, output: 26.85 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.19it/s, est. speed input: 17658.83 toks/s, output: 21.07 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [02:24<00:00, 72.29s/it, est. speed input: 1.40 toks/s, output: 56.66 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [02:02<00:00, 61.24s/it, est. speed input: 0.90 toks/s, output: 57.43 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.13it/s, est. speed input: 18955.36 toks/s, output: 20.71 toks/s]
# Rendering prompts:   0%|          | 0/2 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:00<00:00,  5.24it/s, est. speed input: 22195.24 toks/s, output: 23.68 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [01:05<00:00, 32.76s/it, est. speed input: 1.68 toks/s, output: 61.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  6.11it/s, est. speed input: 13199.84 toks/s, output: 24.86 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:48<00:00, 24.28s/it, est. speed input: 2.27 toks/s, output: 63.27 toks/s]
# Rendering prompts:   0%|          | 0/2 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:00<00:00,  9.13it/s, est. speed input: 14760.48 toks/s, output: 36.63 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [01:06<00:00, 33.25s/it, est. speed input: 3.19 toks/s, output: 61.59 toks/s]
# Rendering prompts:   0%|          | 0/2 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:00<00:00,  7.30it/s, est. speed input: 15923.64 toks/s, output: 36.61 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:31<00:00, 15.78s/it, est. speed input: 2.98 toks/s, output: 64.90 toks/s]
# Rendering prompts:   0%|          | 0/2 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [00:00<00:00,  9.67it/s, est. speed input: 10585.96 toks/s, output: 38.79 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [01:05<00:00, 32.63s/it, est. speed input: 1.44 toks/s, output: 60.82 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  6.10it/s, est. speed input: 13060.95 toks/s, output: 24.69 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [01:00<00:00, 30.24s/it, est. speed input: 1.55 toks/s, output: 61.96 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts: 100%|██████████| 2/2 [01:24<00:00, 42.14s/it, est. speed input: 1.12 toks/s, output: 60.57 toks/s]
